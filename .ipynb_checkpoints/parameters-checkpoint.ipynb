# %%
import numpy as np
import matplotlib.pyplot as plt
from antOptimization import AntColony


def generate_random_distance_matrix(size):
    # 生成一个随机的距离矩阵，矩阵大小为 size x size
    np.random.seed(42)  # 设置随机种子以确保结果的可重复性
    distances = np.random.uniform(1, 100, size=(size, size))  # 生成随机距离，范围1到100
    distances = np.round(distances, 2)

    distances = (distances + distances.T) / 2  # 使矩阵对称，确保距离的一致性
    np.fill_diagonal(distances, np.inf)  # 设置对角线为无穷大，表示自己到自己的距离
    return distances

# %% [markdown]
# 创建子类 AntTime来统计蚁群算法的运行时间，以便后续对时间性能的分析

# %%
import time


class AntTime(AntColony):
    def run(self):
        start_time = time.time()  # Record the start time
        shortest_path = None
        all_time_shortest_path = ("placeholder", np.inf)
        iteration_shortest_paths = []  # List to store each iteration's shortest path
        convergence_threshold = 0.01  # 定义收敛阈值
        convergence_count = 5  # 定义需要连续多少次小于阈值才认为收敛
        convergence_iterations = 0  # 初始化连续达到阈值的次数
        previous_shortest_distance = np.inf  # 初始化前一次的最短路径长度

        for i in range(self.n_iterations):
            all_paths = self.gen_all_paths()
            self.spread_pheronome(all_paths, self.n_best, shortest_path=shortest_path)
            shortest_path = min(all_paths, key=lambda x: x[1])
            iteration_shortest_paths.append(shortest_path[1])  # Append current iteration's shortest distance
            if shortest_path[1] < all_time_shortest_path[1]:
                all_time_shortest_path = shortest_path            
            self.pheromone = self.pheromone * self.decay
            # 判断是否收敛
            distance_improvement = previous_shortest_distance - shortest_path[1]
            if distance_improvement < convergence_threshold:
                convergence_iterations += 1
                # print(distance_improvement)
            else:
                # print(distance_improvement)
                convergence_iterations = 0  # 重置连续达到阈值的次数
            if convergence_iterations >= convergence_count:
                print(f"Algorithm has converged after {i+1} iterations.")
                break  # 收敛，跳出循环            
            previous_shortest_distance = shortest_path[1]  # 更新前一次的最短路径长度
        end_time = time.time()  # Record the end time
        execution_time = end_time - start_time  # Calculate the execution time
        return execution_time, iteration_shortest_paths  # Return the all-time shortest path and list of iteration shortest paths

# %%
# 生成80*80的随机距离矩阵
size = 80
distances = generate_random_distance_matrix(size)
distances
# Out:
# array([[   inf, 90.785, 55.44 , ..., 12.325, 64.275, 37.33 ],
#        [90.785,    inf, 48.68 , ..., 53.61 , 17.46 , 62.265],
#        [55.44 , 48.68 ,    inf, ..., 14.53 , 59.885, 36.78 ],
#        ...,
#        [12.325, 53.61 , 14.53 , ...,    inf, 72.48 , 61.56 ],
#        [64.275, 17.46 , 59.885, ..., 72.48 ,    inf, 24.26 ],
#        [37.33 , 62.265, 36.78 , ..., 61.56 , 24.26 ,    inf]])

# %%
excecution_time=[]
distance=[]
x=[]
for i in range(80,160,5):
    ant_colony = AntTime(distances, n_ants=i, n_best=10,
                                n_iterations=100, decay=0.5, alpha=1, beta=2)
    Time,Distance= ant_colony.run()

    distance.append(Distance[-1])
    x.append(i)
    excecution_time.append(Time)
# Out:
# Algorithm has converged after 29 iterations.
# Algorithm has converged after 47 iterations.
# Algorithm has converged after 35 iterations.
# Algorithm has converged after 36 iterations.
# Algorithm has converged after 30 iterations.
# Algorithm has converged after 29 iterations.
# Algorithm has converged after 35 iterations.
# Algorithm has converged after 18 iterations.
# Algorithm has converged after 37 iterations.
# Algorithm has converged after 21 iterations.
# Algorithm has converged after 29 iterations.
# Algorithm has converged after 26 iterations.
# Algorithm has converged after 24 iterations.
# Algorithm has converged after 30 iterations.
# Algorithm has converged after 24 iterations.
# Algorithm has converged after 20 iterations.

# %%
plt.figure()  # 设置图像大小
plt.bar(x,excecution_time,width=3)  

# 设置图表标题和轴标签
plt.title(f'Excecution Time - Number of Ants')
plt.xlabel('number of elite Ants')
plt.ylabel('Excecution time')
# 显示图表
plt.show()

plt.figure()  # 设置图像大小
plt.bar(x,distance,width=3)  

# 设置图表标题和轴标签
plt.title(f'Min Distance - Number of Ants')
plt.xlabel('number of elite Ants')
plt.ylabel('Excecution time')
# 显示图表
plt.show()

# %%
excecution_time=[]
distance=[]
x=[]
for i in range(6,25,2):
    ant_colony = AntTime(distances, n_ants=120, n_best=i,
                                n_iterations=100, decay=0.5, alpha=1, beta=2)
    Time,Distance= ant_colony.run()

    distance.append(Distance[-1])
    x.append(i)
    excecution_time.append(Time)
# Out:
# Algorithm has converged after 21 iterations.
# Algorithm has converged after 28 iterations.
# Algorithm has converged after 33 iterations.
# Algorithm has converged after 31 iterations.
# Algorithm has converged after 43 iterations.
# Algorithm has converged after 31 iterations.
# Algorithm has converged after 28 iterations.
# Algorithm has converged after 39 iterations.
# Algorithm has converged after 44 iterations.
# Algorithm has converged after 41 iterations.

# %%
plt.figure()  # 设置图像大小
plt.bar(x,excecution_time)  # 画柱状图，X轴是迭代次数，Y轴是距离值

# 设置图表标题和轴标签
plt.title(f'Excecution Time - number of ants')
plt.xlabel('number of Ants')
plt.ylabel('Excecution time')
# 显示图表
plt.show()

plt.figure()  # 设置图像大小
plt.bar(x,distance)  # 画柱状图，X轴是迭代次数，Y轴是距离值

# 设置图表标题和轴标签
plt.title(f'Min Distance - number of ants')
plt.xlabel('number of Ants')
plt.ylabel('Minimal Distance')
# 显示图表
plt.show()

# %%
excecution_time=[]
distance=[]
x=[]
for i in range(2,8,1):
    i=i/10
    ant_colony = AntTime(distances, n_ants=120, n_best=12,
                            n_iterations=100, decay=i, alpha=1, beta=2)
    Time,Distance= ant_colony.run()

    distance.append(Distance[-1])
    x.append(i)
    excecution_time.append(Time)
# Out:
# Algorithm has converged after 23 iterations.
# Algorithm has converged after 21 iterations.
# Algorithm has converged after 26 iterations.
# Algorithm has converged after 43 iterations.
# Algorithm has converged after 37 iterations.
# Algorithm has converged after 53 iterations.

# %%
plt.figure()  # 设置图像大小
plt.bar(x,excecution_time,width=0.09)  # 画柱状图，X轴是迭代次数，Y轴是距离值

# 设置图表标题和轴标签
plt.title(f'Excecution Time - Decay')
plt.xlabel('decay')
plt.ylabel('Excecution time')
# 显示图表
plt.show()


plt.figure()  # 设置图像大小
plt.bar(x,distance,width=0.09)  # 画柱状图，X轴是迭代次数，Y轴是距离值

# 设置图表标题和轴标签
plt.title(f'Min Distance - Decay')
plt.xlabel('decay')
plt.ylabel('Minimal Distance')
# 显示图表
plt.show()

# %%
excecution_time=[]
distance=[]
x=[]
for i in range(10,20,2):
    i=i/10
    ant_colony = AntTime(distances, n_ants=120, n_best=12,
                            n_iterations=100, decay=0.6, alpha=i, beta=2)
    Time,Distance= ant_colony.run()

    distance.append(Distance[-1])
    x.append(i)
    excecution_time.append(Time)
# Out:
# Algorithm has converged after 43 iterations.
# Algorithm has converged after 24 iterations.
# Algorithm has converged after 28 iterations.
# Algorithm has converged after 22 iterations.
# Algorithm has converged after 17 iterations.

# %%
plt.figure()  # 设置图像大小
plt.bar(x,excecution_time,width=0.15)  # 画柱状图，X轴是迭代次数，Y轴是距离值

# 设置图表标题和轴标签
plt.title(f'Excecution Time - alpha')
plt.xlabel('Alpha')
plt.ylabel('Excecution time')
# 显示图表
plt.show()


plt.figure()  # 设置图像大小
plt.bar(x,distance,width=0.15)  # 画柱状图，X轴是迭代次数，Y轴是距离值

# 设置图表标题和轴标签
plt.title(f'Min Distance - alpha')
plt.xlabel('Alpha')
plt.ylabel('Minimal distance')
# 显示图表
plt.show()

# %%
excecution_time=[]
distance=[]
x=[]
for i in range(10,30,2):
    i=i/10
    ant_colony = AntTime(distances, n_ants=120, n_best=12,
                            n_iterations=100, decay=0.6, alpha=1.2, beta=i)
    Time,Distance= ant_colony.run()

    distance.append(Distance[-1])
    x.append(i)
    excecution_time.append(Time)
# Out:
# Algorithm has converged after 27 iterations.
# Algorithm has converged after 24 iterations.
# Algorithm has converged after 24 iterations.
# Algorithm has converged after 20 iterations.
# Algorithm has converged after 33 iterations.
# Algorithm has converged after 26 iterations.
# Algorithm has converged after 30 iterations.
# Algorithm has converged after 31 iterations.
# Algorithm has converged after 32 iterations.
# Algorithm has converged after 19 iterations.

# %%
plt.figure()  # 设置图像大小
plt.bar(x,excecution_time,width=0.1)  # 画柱状图，X轴是迭代次数，Y轴是距离值

# 设置图表标题和轴标签
plt.title(f'Iteration - beta')
plt.xlabel('Beta')
plt.ylabel('Excecution time')
# 显示图表
plt.show()

plt.figure()  # 设置图像大小
plt.bar(x,distance,width=0.1)  # 画柱状图，X轴是迭代次数，Y轴是距离值

# 设置图表标题和轴标签
plt.title(f'Min Distance - beta')
plt.xlabel('Beta')
plt.ylabel('Minimal distance')
# 显示图表
plt.show()

# %% [markdown]
# 循环运行检查优化后的性能

# %%
totalDis = 0
for i in range(1,11):
    ant_colony = AntColony(distances, n_ants=120, n_best=12,
                                n_iterations=100, decay=0.6, alpha=1.2, beta=2.2)
    shortest_path,dis, iterations = ant_colony.run() 
    totalDis += dis[-1]   
    print(f'optimal distance = {dis[-1]}')

meandis = totalDis/10
print('mean distance=',meandis)
# Out:
# Algorithm has converged after 30 iterations.
# optimal distance = 923.0050000000002
# Algorithm has converged after 16 iterations.
# optimal distance = 940.9100000000002
# Algorithm has converged after 24 iterations.
# optimal distance = 906.4750000000001
# Algorithm has converged after 23 iterations.
# optimal distance = 919.4150000000004
# Algorithm has converged after 22 iterations.
# optimal distance = 941.5550000000002
# Algorithm has converged after 26 iterations.
# optimal distance = 943.9900000000004
# Algorithm has converged after 21 iterations.
# optimal distance = 931.0700000000002
# Algorithm has converged after 24 iterations.
# optimal distance = 900.1000000000003
# Algorithm has converged after 25 iterations.
# optimal distance = 953.0799999999999
# Algorithm has converged after 19 iterations.
# optimal distance = 908.5050000000003
# mean distance= 926.8105000000003

# %%
totalDis = 0
for i in range(1,11):
    ant_colony = AntColony(distances, n_ants=100, n_best=10,
                                n_iterations=100, decay=0.8, alpha=1, beta=2)
    shortest_path,dis, iterations = ant_colony.run() 
    totalDis += dis[-1]   
    print(f'optimal distance = {dis[-1]}')

meandis = totalDis/10
print('mean distance=',meandis)
# Out:
# Algorithm has converged after 76 iterations.
# optimal distance = 912.1100000000002
# Algorithm has converged after 82 iterations.
# optimal distance = 936.1450000000002
# Algorithm has converged after 59 iterations.
# optimal distance = 929.6500000000001
# Algorithm has converged after 51 iterations.
# optimal distance = 880.2900000000001
# Algorithm has converged after 57 iterations.
# optimal distance = 901.4300000000003
# Algorithm has converged after 67 iterations.
# optimal distance = 913.8850000000002
# Algorithm has converged after 53 iterations.
# optimal distance = 927.3599999999999
# Algorithm has converged after 77 iterations.
# optimal distance = 922.9700000000004
# Algorithm has converged after 57 iterations.
# optimal distance = 900.9450000000002
# Algorithm has converged after 59 iterations.
# optimal distance = 932.6000000000001
# mean distance= 915.7385000000002

# %% [markdown]
# 发现了模型寻找最优解能力下降的情况：
# 分析影响来源：由于优化过程中过于看重时间性能从而多次选择了容易让模型陷入局部最优的快速收敛中。虽然时间性能提升，但是搜寻最优解的能力却降低
#
# 解决方法：算法前期重探索，后期重收敛，这样既可以搜索到足够多的路径还可以快速收敛
#
# 技术手段：实施动态参数调整，随着迭代进行改变alpha, beta的值，前期a小b大，后期a大b小

# %%
import numpy as np

class AntColonyOptimize(AntColony):
    def run(self):
        shortest_path = None
        all_time_shortest_path = ("placeholder", np.inf)
        iteration_shortest_paths = []  # List to store each iteration's shortest path
        convergence_threshold = 0.01  # 定义收敛阈值
        convergence_count = 5  # 定义需要连续多少次小于阈值才认为收敛
        convergence_iterations = 0  # 初始化连续达到阈值的次数
        previous_shortest_distance = np.inf  # 初始化前一次的最短路径长度

        # 自适应参数初始化
        initial_alpha = self.alpha
        initial_beta = self.beta
        alpha_increment = (2 - self.alpha) / (1+self.n_iterations)  # 根据迭代次数线性增加alpha值
        beta_decrement = self.beta / (1+self.n_iterations)  # 根据迭代次数线性减少beta值

        for i in range(self.n_iterations):
            # 自适应策略调整alpha和beta
            self.alpha += alpha_increment
            self.beta -= beta_decrement

            all_paths = self.gen_all_paths()
            self.spread_pheronome(all_paths, self.n_best, shortest_path=shortest_path)
            shortest_path = min(all_paths, key=lambda x: x[1])
            iteration_shortest_paths.append(shortest_path[1])  # Append current iteration's shortest distance
            if shortest_path[1] < all_time_shortest_path[1]:
                all_time_shortest_path = shortest_path            
            self.pheromone = self.pheromone * self.decay
            # 判断是否收敛
            distance_improvement = previous_shortest_distance - shortest_path[1]
            if distance_improvement < convergence_threshold:
                convergence_iterations += 1
            else:
                convergence_iterations = 0  # 重置连续达到阈值的次数
            if convergence_iterations >= convergence_count:
                print(f"Algorithm has converged after {i+1} iterations.")
                break  # 收敛，跳出循环            
            previous_shortest_distance = shortest_path[1]  # 更新前一次的最短路径长度
        
        # 恢复alpha和beta的初始值
        self.alpha = initial_alpha
        self.beta = initial_beta

        return all_time_shortest_path, iteration_shortest_paths, i+1  # Return the all-time shortest path and list of iteration shortest paths

# %%
totalDis = 0
for i in range(1,11):
    ant_colony = AntColonyOptimize(distances, n_ants=120, n_best=12,
                                n_iterations=100, decay=0.5, alpha=0.4, beta=2)
    shortest_path,dis, iterations = ant_colony.run() 
    totalDis += dis[-1]   
    print(f'optimal distance = {dis[-1]}')

meandis = totalDis/10
print('mean distance=',meandis)
# Out:
# Algorithm has converged after 49 iterations.
# optimal distance = 911.57
# Algorithm has converged after 52 iterations.
# optimal distance = 893.3300000000002
# Algorithm has converged after 55 iterations.
# optimal distance = 910.4850000000004
# Algorithm has converged after 53 iterations.
# optimal distance = 896.6850000000004
# Algorithm has converged after 53 iterations.
# optimal distance = 885.9200000000003
# Algorithm has converged after 55 iterations.
# optimal distance = 903.0650000000004
# Algorithm has converged after 51 iterations.
# optimal distance = 903.5999999999997
# Algorithm has converged after 50 iterations.
# optimal distance = 899.6250000000002
# Algorithm has converged after 53 iterations.
# optimal distance = 895.7100000000003
# Algorithm has converged after 60 iterations.
# optimal distance = 925.6350000000004
# mean distance= 902.5625000000002
